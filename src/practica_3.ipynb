# %% [markdown]
# # Practica 4: optimizacion con el moduloi sipy

# %% [markdown]
# ## 4.1 Optimizacion para una función no deribable pero convexa

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def objective(v):
    x, y = v
    f = np.sqrt(x**2 + y**2)
    return f

# %%
r_min, r_max = -1.0, 1.0
xaxis = np.arange(r_min, r_max, 0.1)
yaxis = np.arange(r_min, r_max, 0.1)
x, y = np.meshgrid(xaxis, yaxis)
v = x, y
result = objective(v)

fig, ax =  plt.subplots(subplot_kw={'projection':'3d'}, figsize=(30,30))
ax.plot_surface(x, y, result, cmap='jet')

plt.show()

# %%
from scipy.optimize import minimize

# %%
initial_guess =r_min + np.random.rand(2) * (r_max - r_min)

result = minimize(objective, initial_guess, method='powell')


print("Estado: %s" %result['message'])
print("Nñumero total de evaluaciones de la funcion objetivo: %d" %result['nfev'])
print("Solucion =", result['x'])

solution = result['x']
print("(solucion) =", objective(solution))
# Out:
# Estado: Optimization terminated successfully.
# Nñumero total de evaluaciones de la funcion objetivo: 236
# Solucion = [ 2.75865306e-12 -3.16363532e-12]
# (solucion) = 4.197470085179185e-12

# %% [markdown]
# ## 4.2 Optimizacion de una funcion derobable pero no convexa

# %%
# funcion de Ackley
def ackley(v):
    x, y = v
    f = -20.0 * np.exp(-0,2 * np.sqrt(0.5 * (x**2 + y**2))) - np.exp(0.5 * (np.cos(2 * np.pi * x) + np.cos(2 * np.pi * y))) + np.e + 20
    return f

# %%
r_min, r_max = -5.0, 5.0
xaxis = np.arange(r_min, r_max, 0.1)
yaxis = np.arange(r_min, r_max, 0.1)
x, y = np.meshgrid(xaxis, yaxis)
v = x, y
result = ackley(v)

fig, ax =  plt.subplots(subplot_kw={'projection':'3d'})
ax.plot_surface(x, y, result, cmap='jet')

plt.show()

# %%
initial_guess =r_min + np.random.rand(2) * (r_max - r_min)

result = minimize(ackley, initial_guess, method='powell')


print("Estado: %s" %result['message'])
print("Nñumero total de evaluaciones de la funcion objetivo: %d" %result['nfev'])
print("Solucion =", result['x'])

solution = result['x']
print("(solucion) =", ackley(solution))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[251], line 3
#       1 initial_guess =r_min + np.random.rand(2) * (r_max - r_min)
# ----> 3 result = minimize(ackley, initial_guess, method='powell')
#       6 print("Estado: %s" %result['message'])
#       7 print("Nñumero total de evaluaciones de la funcion objetivo: %d" %result['nfev'])
#
# File ~/anaconda3/envs/optim-2/lib/python3.9/site-packages/scipy/optimize/_minimize.py:704, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     701     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     702                                **options)
#     703 elif meth == 'powell':
# --> 704     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#     705 elif meth == 'cg':
#     706     res = _minimize_cg(fun, x0, args, jac, callback, **options)
# ...
